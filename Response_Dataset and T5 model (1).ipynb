# %%
import pandas as pd
df = pd.read_csv('/content/emotion-emotion_69k.csv')
df.head()
# Out:
#    Unnamed: 0                                          Situation      emotion  \
# 0           0  I remember going to the fireworks with my best...  sentimental
# 1           1  I remember going to the fireworks with my best...  sentimental
# 2           2  I remember going to the fireworks with my best...  sentimental
# 3           3  I remember going to the fireworks with my best...  sentimental
# 4           4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels Unnamed: 5 Unnamed: 6
# 0  Was this a friend you were in love with, or ju...        NaN        NaN
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                          Situation      emotion  \
# 0           0  I remember going to the fireworks with my best...  sentimental
# 1           1  I remember going to the fireworks with my best...  sentimental
# 2           2  I remember going to the fireworks with my best...  sentimental
# 3           3  I remember going to the fireworks with my best...  sentimental
# 4           4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels Unnamed: 5 Unnamed: 6
# 0  Was this a friend you were in love with, or ju...        NaN        NaN
# ...

# %%
df = df.drop(columns=["Unnamed: 0", "Unnamed: 5", "Unnamed: 6"])

# %%
df = df.dropna(subset=["empathetic_dialogues", "labels"])

# %%
print("Columns in DataFrame:", df.columns.tolist())
# Out:
# Columns in DataFrame: ['Situation', 'emotion', 'empathetic_dialogues', 'labels']

# %%
required_columns = ["Situation", "emotion", "labels"]
missing = [col for col in required_columns if col not in df.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")

df = df.dropna(subset=["Situation", "emotion", "labels"])

# %%
df.isnull().sum()
# Out:
# Situation               0
# emotion                 0
# empathetic_dialogues    0
# labels                  0
# dtype: int64

# %%
df.shape
# Out:
# (64632, 4)

# %%
print(f"{'Prompt':<50} | {'Response':<50}")
print("-"*100)
for idx in range(3):
    print(f"{df['empathetic_dialogues'].iloc[idx][:45]:<50} | {df['labels'].iloc[idx][:45]:<50}")
# Out:
# Prompt                                             | Response
# ----------------------------------------------------------------------------------------------------
# Customer :I remember going to see the firewor      | Was this a friend you were in love with, or j
# Customer :This was a best friend. I miss her.      | Where has she gone?
# Customer :We no longer talk.
# Agent :               | Oh was this something that happened because o

# %%
def split_dialogue(text):
    parts = text.split('\nAgent :')
    customer = parts[0].replace('Customer :', '').strip()
    agent = parts[1].strip() if len(parts) > 1 else ''
    return customer, agent

df[['customer_input', 'agent_response']] = df['empathetic_dialogues'].apply(
    lambda x: pd.Series(split_dialogue(x)) # Changed 'split_dialogues' to 'split_dialogue'
)

# %%
df.head()
# Out:
#                                            Situation      emotion  \
# 0  I remember going to the fireworks with my best...  sentimental
# 1  I remember going to the fireworks with my best...  sentimental
# 2  I remember going to the fireworks with my best...  sentimental
# 3  I remember going to the fireworks with my best...  sentimental
# 4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels  \
# 0  Was this a friend you were in love with, or ju...
# 1                                Where has she gone?
# 2  Oh was this something that happened because of...
# ...

# %%
df['emotion_context_input'] = df['emotion'] + ": " + df['customer_input']

# %%
df.head()
# Out:
#                                            Situation      emotion  \
# 0  I remember going to the fireworks with my best...  sentimental
# 1  I remember going to the fireworks with my best...  sentimental
# 2  I remember going to the fireworks with my best...  sentimental
# 3  I remember going to the fireworks with my best...  sentimental
# 4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels  \
# 0  Was this a friend you were in love with, or ju...
# 1                                Where has she gone?
# 2  Oh was this something that happened because of...
# ...

# %%
df.head()
# Out:
#                                            Situation      emotion  \
# 0  I remember going to the fireworks with my best...  sentimental
# 1  I remember going to the fireworks with my best...  sentimental
# 2  I remember going to the fireworks with my best...  sentimental
# 3  I remember going to the fireworks with my best...  sentimental
# 4  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
# 2              Customer :We no longer talk.\nAgent :
# 3  Customer :Was this a friend you were in love w...
# 4             Customer :Where has she gone?\nAgent :
#
#                                               labels  \
# 0  Was this a friend you were in love with, or ju...
# 1                                Where has she gone?
# 2  Oh was this something that happened because of...
# ...

# %%
# Keep only essential columns
df = df[['Situation', 'labels', 'emotion']]

# Rename for clarity
df = df.rename(columns={
    'Situation': 'context',
    'labels': 'response'
})

# Clean remaining data
df = df.dropna()
df = df[df['response'].str.strip().astype(bool)]

# %%
df.head()
# Out:
#                                              context  \
# 0  I remember going to the fireworks with my best...
# 1  I remember going to the fireworks with my best...
# 2  I remember going to the fireworks with my best...
# 3  I remember going to the fireworks with my best...
# 4  I remember going to the fireworks with my best...
#
#                                             response      emotion
# 0  Was this a friend you were in love with, or ju...  sentimental
# 1                                Where has she gone?  sentimental
# 2  Oh was this something that happened because of...  sentimental
# 3                This was a best friend. I miss her.  sentimental
# 4                                 We no longer talk.  sentimental

# %%
# Format input with context + emotion
df['input_text'] = df.apply(
    lambda x: f"CONTEXT: {x['context']} EMOTION: {x['emotion']}",
    axis=1
)

print(df[['input_text', 'response']].head(2))
# Out:
#                                           input_text  \
# 0  CONTEXT: I remember going to the fireworks wit...
# 1  CONTEXT: I remember going to the fireworks wit...
#
#                                             response
# 0  Was this a friend you were in love with, or ju...
# 1                                Where has she gone?

# %% [markdown]
# graph LR
#     A[Input Text] --> B[DistilBERT Encoder]
#     B --> C[Encoder Outputs]
#     C --> D[Decoder]
#     D --> E[Empathetic Response]

# %% [markdown]
# saved model

# %%
df.head()
# Out:
#                                              context  \
# 0  I remember going to the fireworks with my best...
# 1  I remember going to the fireworks with my best...
# 2  I remember going to the fireworks with my best...
# 3  I remember going to the fireworks with my best...
# 4  I remember going to the fireworks with my best...
#
#                                             response      emotion  \
# 0  Was this a friend you were in love with, or ju...  sentimental
# 1                                Where has she gone?  sentimental
# 2  Oh was this something that happened because of...  sentimental
# 3                This was a best friend. I miss her.  sentimental
# 4                                 We no longer talk.  sentimental
#
#                                           input_text
# 0  CONTEXT: I remember going to the fireworks wit...
# 1  CONTEXT: I remember going to the fireworks wit...
# 2  CONTEXT: I remember going to the fireworks wit...
# ...

# %%
# prompt: download df dataset

# %%
pip install transformers torch datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 881.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# Load directly from Hub
emotion_classifier = pipeline(
    "text-classification",
    model="abhay2727/emotion_model",
    tokenizer="abhay2727/emotion_model"
)

# Label mapping should match your model's training setup
label_mapping = {
    0: "neutral",
    1: "anger",
    2: "fear",
    3: "surprise",
    4: "happiness",
    5: "sadness",
    6: "disgust"
}

def classify_emotion(text):
    result = emotion_classifier(text)[0]
    return label_mapping[int(result['label'].split("_")[-1])]

# Example usage
print(classify_emotion("Chatgpt is taking iver the job market. I am very concerned about my job, even though I have tea stall outside an IT company."))  # Should return "happiness"
# Out:
# Device set to use cpu
# fear

# %%
accelerator = Accelerator(
    mixed_precision='fp16',
    gradient_accumulation_steps=4
)

# %%
pip install datasets

# %%
from accelerate import Accelerator
from transformers import (
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
from torch.utils.data import DataLoader
import torch
from datasets import load_dataset
from torch.optim import AdamW # Import AdamW from torch.optim

# %%
from datasets import load_dataset, Dataset, DatasetDict
dataset = Dataset.from_pandas(df)
tokenizer = T5Tokenizer.from_pretrained("t5-base")

# %%
split_dataset = dataset.train_test_split(test_size=0.2, seed=42)
test_valid = split_dataset['test'].train_test_split(test_size=0.5, seed=42)

dataset = DatasetDict({
    'train': split_dataset['train'],
    'validation': test_valid['train'],
    'test': test_valid['test']
})

# %%
def tokenize_function(examples):
    # Create input text with emotion and context
    inputs = [
        f"emotion: {emotion} context: {context}"
        for emotion, context in zip(examples['emotion'], examples['input_text'])
    ]

    # Tokenize both inputs and targets
    model_inputs = tokenizer(
        inputs,
        max_length=128,
        truncation=True,
        padding="max_length"
    )

    # Tokenize targets (responses)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples['response'],
            max_length=128,
            truncation=True,
            padding="max_length"
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_dataset = dataset.map(tokenize_function, batched=True)
tokenized_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/51705 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3980: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# ...
# Map:   0%|          | 0/6464 [00:00<?, ? examples/s]

# %%
train_dataloader = DataLoader(
    tokenized_dataset["train"],
    shuffle=True,
    batch_size=8,
    collate_fn=lambda batch: {
        'input_ids': torch.stack([x['input_ids'] for x in batch]),
        'attention_mask': torch.stack([x['attention_mask'] for x in batch]),
        'labels': torch.stack([x['labels'] for x in batch])
    }
)

# %%
val_dataloader = DataLoader(
    tokenized_dataset["validation"],
    batch_size=8,
    collate_fn=lambda batch: {
        'input_ids': torch.stack([x['input_ids'] for x in batch]),
        'attention_mask': torch.stack([x['attention_mask'] for x in batch]),
        'labels': torch.stack([x['labels'] for x in batch])
    }
)

# %%
model = T5ForConditionalGeneration.from_pretrained("t5-base")
optimizer = AdamW(model.parameters(), lr=3e-5, weight_decay=0.01)
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=500,
    num_training_steps=len(train_dataloader)*5
)
# Out:
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
model, optimizer, train_dataloader, val_dataloader, scheduler = accelerator.prepare(
    model, optimizer, train_dataloader, val_dataloader, scheduler
)

# %%
for epoch in range(5):
    # Training
    model.train()
    total_loss = 0

    for step, batch in enumerate(train_dataloader):
        with accelerator.accumulate(model):
            outputs = model(
                input_ids=batch['input_ids'],
                attention_mask=batch['attention_mask'],
                labels=batch['labels']
            )

            loss = outputs.loss
            accelerator.backward(loss)

            # Gradient clipping
            accelerator.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            total_loss += loss.item()

            if step % 100 == 0:
                accelerator.print(f"Epoch {epoch} | Step {step} | Loss: {loss.item():.4f}")

    # Validation
    model.eval()
    val_loss = 0
    for batch in val_dataloader:
        with torch.no_grad():
            outputs = model(
                input_ids=batch['input_ids'],
                attention_mask=batch['attention_mask'],
                labels=batch['labels']
            )
        val_loss += outputs.loss.item()

    # Generate sample responses
    sample_input = "emotion: sadness context: I lost my job today"
    input_ids = tokenizer.encode(sample_input, return_tensors="pt").to(accelerator.device)
    generated = model.generate(
        input_ids,
        max_length=128,
        num_beams=5,
        temperature=0.7,
        early_stopping=True
    )
    sample_output = tokenizer.decode(generated[0], skip_special_tokens=True)

    accelerator.print(f"\nEpoch {epoch} Summary:")
    accelerator.print(f"Train Loss: {total_loss/len(train_dataloader):.4f}")
    accelerator.print(f"Val Loss: {val_loss/len(val_dataloader):.4f}")
    accelerator.print(f"Sample Response: {sample_output}\n")
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Epoch 0 | Step 0 | Loss: 16.5497
# Epoch 0 | Step 100 | Loss: 17.5158
# Epoch 0 | Step 200 | Loss: 14.4955

# %%
accelerator.wait_for_everyone()
accelerator.save_state(output_dir="./emotion_response_model")
accelerator.save_model(model, "./emotion_response_model")
